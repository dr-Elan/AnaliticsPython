# %%
import pandas as pd

# %%
laptop = pd.read_csv('https://gbcdn.mrgcdn.ru/uploads/asset/4957768/attachment/79dce5d9a8cff55bf57542ae9b63338f.csv', encoding='windows-1251')
laptop.describe()
# Out:
#          laptop_ID       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000

# %%
laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
laptop.isna().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
laptop
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
laptop['Company'].value_counts().max()
# Out:
# 297

# %%
laptop.sort_values('Price_euros', ascending=False).iloc[0]
# Out:
# laptop_ID                                           200
# Company                                           Razer
# Product                                       Blade Pro
# TypeName                                         Gaming
# Inches                                             17.3
# ScreenResolution    4K Ultra HD / Touchscreen 3840x2160
# Cpu                         Intel Core i7 7820HK 2.9GHz
# Ram                                                32GB
# Memory                                          1TB SSD
# Gpu                             Nvidia GeForce GTX 1080
# OpSys                                        Windows 10
# Weight                                           3.49kg
# Price_euros                                      6099.0
# Name: 196, dtype: object

# %%
laptop[laptop["Company"] == laptop["Price_euros"].max()]
# Out:
# Empty DataFrame
# Columns: [laptop_ID, Company, Product, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price_euros]
# Index: []

# %%
laptop[laptop["Price_euros"] == laptop["Price_euros"].max()]
# Out:
#      laptop_ID Company    Product TypeName  Inches  \
# 196        200   Razer  Blade Pro   Gaming    17.3
#
#                         ScreenResolution                          Cpu   Ram  \
# 196  4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz  32GB
#
#       Memory                      Gpu       OpSys  Weight  Price_euros
# 196  1TB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg       6099.0

# %% [markdown]
# Ответьте на несколько вопросов
# 4.1 Найдите ноутбуки с самой маленькой диагональю в данных?
# Выведите только следующие характеристики:
# Компания
# Типа ноутбука
# Диагональ
# Стоимость
# Если таких ноутбуков несколько, то выводите их всех
# 4.2 Сколько стоит самый дорогой ноутбук у компании HP?
# 4.3 Как много ноутбуков Ultrabook с 8GB RAM?
# Найдите сколько таких ультрабуков с 8GB ОЗУ в процентном соотношении относительно всех ультрабуков

# %%
laptop.sort_values(['Inches']).head(4)
# Out:
#       laptop_ID Company    Product            TypeName  Inches  \
# 1114       1129  Lenovo  Yoga Book  2 in 1 Convertible    10.1
# 1126       1141  Lenovo  Yoga Book  2 in 1 Convertible    10.1
# 1082       1097  Lenovo  Yoga Book  2 in 1 Convertible    10.1
# 50           51  Lenovo  Yoga Book  2 in 1 Convertible    10.1
#
#                      ScreenResolution                          Cpu  Ram  \
# 1114  IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
# 1126  IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
# 1082  IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
# 50    IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
#
#                   Memory                    Gpu       OpSys  Weight  \
# 1114  64GB Flash Storage  Intel HD Graphics 400     Android  0.69kg
# 1126  64GB Flash Storage  Intel HD Graphics 400  Windows 10  0.69kg
# 1082  64GB Flash Storage  Intel HD Graphics 400  Windows 10  0.69kg
# ...

# %%
laptop[laptop["Inches"] == laptop["Inches"].min()][["Company", "TypeName", "Inches", "Price_euros"]]
# Out:
#      Company            TypeName  Inches  Price_euros
# 50    Lenovo  2 in 1 Convertible    10.1       319.00
# 1082  Lenovo  2 in 1 Convertible    10.1       646.27
# 1114  Lenovo  2 in 1 Convertible    10.1       549.00
# 1126  Lenovo  2 in 1 Convertible    10.1       479.00

# %%
laptop[laptop["Price_euros"] == laptop["Price_euros"].max()]['Price_euros']
# Out:
# 196    6099.0
# Name: Price_euros, dtype: float64

# %%
laptop['Price_euros'].max()
# Out:
# 6099.0

# %%
laptop[laptop['Company'] == 'HP']['Price_euros'].max()
# Out:
# 4389.0

# %%
laptop[(laptop['TypeName'] == 'Ultrabook') & (laptop['Ram'] == '8GB') ]
# Out:
#       laptop_ID Company               Product   TypeName  Inches  \
# 0             1   Apple           MacBook Pro  Ultrabook    13.3
# 1             2   Apple           Macbook Air  Ultrabook    13.3
# 4             5   Apple           MacBook Pro  Ultrabook    13.3
# 7             8   Apple           Macbook Air  Ultrabook    13.3
# 9            10    Acer               Swift 3  Ultrabook    14.0
# ...         ...     ...                   ...        ...     ...
# 1236       1254      HP         EliteBook 840  Ultrabook    14.0
# 1241       1259    Asus  ZenBook UX310UA-WB71  Ultrabook    13.3
# 1261       1279    Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
# 1275       1293    Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
# 1289       1307    Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
#
#                         ScreenResolution                         Cpu  Ram  \
# 0     IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# ...

# %%
laptop[(laptop['TypeName'] == 'Ultrabook') & (laptop['Ram'] == '8GB') ].value_counts(normalize=True)
# Out:
# laptop_ID  Company  Product               TypeName   Inches  ScreenResolution                     Cpu                         Ram  Memory     Gpu                           OpSys       Weight  Price_euros
# 1          Apple    MacBook Pro           Ultrabook  13.3    IPS Panel Retina Display 2560x1600   Intel Core i5 2.3GHz        8GB  128GB SSD  Intel Iris Plus Graphics 640  macOS       1.37kg  1339.69        0.007143
# 924        HP       Elitebook Folio       Ultrabook  12.5    4K Ultra HD / Touchscreen 3840x2160  Intel Core M 6Y75 1.2GHz    8GB  240GB SSD  Intel HD Graphics 515         Windows 10  1.09kg  3100.00        0.007143
# 886        Dell     Latitude 7280         Ultrabook  12.5    Full HD 1920x1080                    Intel Core i7 7600U 2.8GHz  8GB  256GB SSD  Intel HD Graphics 620         Windows 10  1.6kg   1690.00        0.007143
# ...

# %%
laptop[(laptop['TypeName'] == 'Ultrabook')]['Ram'].value_counts(normalize=True)
# Out:
# 8GB     0.714286
# 16GB    0.183673
# 4GB     0.071429
# 12GB    0.015306
# 24GB    0.005102
# 32GB    0.005102
# 6GB     0.005102
# Name: Ram, dtype: float64

# %% [markdown]
# 5.1 Выберите ноутбук клиенту
# Клиент хочет подобрать ноутбук с 8GB или 16GB ОЗУ на Windows 10 в стоимости до 500 евро, сколько у него вариантов?
#
# 5.2 Выберите ноутбук клиенту
# Клиент хочет подобрать ноутбук от MSI, с видеокартой Nvidia GeForce GTX 1050 Ti и главное не с диагональю 15.6. В какой ценовой категории вышли подобные ноутбуки?
#
# 5.3 Что дешевле?
# В среднем дешевле ноутбуки с CPU Intel Core i7 7700HQ 2.8GHz или с Intel Core i7 7600U 2.8GHz?

# %%
laptop[(laptop['Ram']=='8GB')&(laptop['OpSys']=='Windows 10')]
# Out:
#       laptop_ID Company               Product            TypeName  Inches  \
# 9            10    Acer               Swift 3           Ultrabook    14.0
# 16           17    Dell         Inspiron 3567            Notebook    15.6
# 19           20    Dell                XPS 13           Ultrabook    13.3
# 21           22  Lenovo    Legion Y520-15IKBN              Gaming    15.6
# 23           24    Dell         Inspiron 5379  2 in 1 Convertible    13.3
# ...         ...     ...                   ...                 ...     ...
# 1265       1283  Lenovo    IdeaPad Y700-15ISK            Notebook    15.6
# 1275       1293    Asus  ZenBook UX305CA-UBM1           Ultrabook    13.3
# 1279       1297  Lenovo    IdeaPad Y700-15ISK            Notebook    15.6
# 1289       1307    Asus  ZenBook UX305CA-UBM1           Ultrabook    13.3
# 1293       1311  Lenovo    IdeaPad Y700-15ISK            Notebook    15.6
#
#                                ScreenResolution                          Cpu  \
# ...

# %%
laptop[laptop['Ram'].isin(['8GB', '16GB']) & (laptop['OpSys']=='Windows 10') & (laptop['Price_euros']<500)]
# Out:
#       laptop_ID Company                                   Product  TypeName  \
# 74           76    Acer                             Aspire E5-475  Notebook
# 175         179    Dell                             Inspiron 3567  Notebook
# 256         261      HP        15-BW094nd (A6-9220/8GB/128GB/W10)  Notebook
# 292         297      HP         17-BS037cl (i3-6006U/8GB/1TB/W10)  Notebook
# 313         318    Acer  ES1-523-84K7 (A8-7410/8GB/256GB/FHD/W10)  Notebook
# 365         371      HP            15-AY023na (N3710/8GB/2TB/W10)  Notebook
# 571         578      HP            14-am079na (N3710/8GB/2TB/W10)  Notebook
# 595         602  Lenovo                         IdeaPad 110-15ISK  Notebook
# 634         642    Asus         X541NA-GO414T (N3350/8GB/1TB/W10)  Notebook
# 702         710  Lenovo                         IdeaPad 320-15ABR  Notebook
# 1057       1071    Acer                            Aspire ES1-523  Notebook
# ...

# %%
laptop[(laptop['Company']=='MSI') & (laptop['Gpu']=='Nvidia GeForce GTX 1050 Ti') & (laptop['Inches']!= 15.6)]
# Out:
#       laptop_ID Company        Product TypeName  Inches   ScreenResolution  \
# 330         336     MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 393         400     MSI  Leopard GP72M   Gaming    17.3  Full HD 1920x1080
# 724         732     MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 917         931     MSI     GE72VR 6RF   Gaming    17.3  Full HD 1920x1080
# 1156       1174     MSI     GP72M 7REX   Gaming    17.3  Full HD 1920x1080
#
#                               Cpu   Ram                Memory  \
# 330   Intel Core i7 7700HQ 2.8GHz   8GB  256GB SSD +  1TB HDD
# 393   Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 724   Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 917   Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 1156  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
#
#                              Gpu       OpSys Weight  Price_euros
# 330   Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg      1199.00
# ...

# %%
laptop[laptop['Cpu'].isin(['Intel Core i7 7600U 2.8GHz']) ]['Price_euros'].mean()
# Out:
# 1915.710769230769

# %%
laptop[laptop['Cpu'].isin(['Intel Core i7 7700HQ 2.8GHz']) ]['Price_euros'].mean()
# Out:
# 1760.4084246575342

# %%
laptop[laptop['Weight']==laptop['Weight'].min()]['Weight'].str.replace('kg','').astype('float')
# Out:
# 50      0.69
# 1082    0.69
# 1114    0.69
# 1126    0.69
# Name: Weight, dtype: float64
